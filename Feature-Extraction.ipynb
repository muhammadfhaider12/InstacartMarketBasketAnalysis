# %%
import numpy as np
import pandas as pd
from category_encoders.binary import BinaryEncoder
import gc

# %%
orders = pd.read_csv('orders.csv')
order_product_prior = pd.read_csv('order_products__prior.csv')
order_product_train = pd.read_csv('order_products__train.csv')
products = pd.read_csv('products.csv')
aisles=pd.read_csv('aisles.csv')
departments = pd.read_csv('departments.csv')

# %%
train_order_df = orders.merge(order_product_prior, on='order_id', how='inner')
train_order_df = train_order_df.merge(products, on='product_id', how='left')
train_order_df = train_order_df.merge(aisles, on='aisle_id', how='left')
train_order_df = train_order_df.merge(departments, on='department_id', how='left')
train_order_df.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2539329        1    prior             1          2                  8
# 2   2539329        1    prior             1          2                  8
# 3   2539329        1    prior             1          2                  8
# 4   2539329        1    prior             1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  aisle_id  department_id  \
# 0                                     Soda        77              7
# 1  Organic Unsweetened Vanilla Almond Milk        91             16
# 2                      Original Beef Jerky        23             19
# 3               Aged White Cheddar Popcorn        23             19
# 4         XL Pick-A-Size Paper Towel Rolls        54             17
#
#              aisle  department
# 0      soft drinks   beverages
# 1  soy lactosefree  dairy eggs
# 2    popcorn jerky      snacks
# 3    popcorn jerky      snacks
# 4      paper goods   household

# %%
train_order_df.isnull().any()
# Out:
# order_id                  False
# user_id                   False
# eval_set                  False
# order_number              False
# order_dow                 False
# order_hour_of_day         False
# days_since_prior_order     True
# product_id                False
# add_to_cart_order         False
# reordered                 False
# product_name              False
# aisle_id                  False
# department_id             False
# aisle                     False
# department                False
# dtype: bool

# %%
train_order_df['days_since_prior_order']=train_order_df['days_since_prior_order'].fillna(0)

# %%
train_order_df['total_products_by_user']=train_order_df.groupby(['user_id','product_id']).cumcount()+1
train_order_df.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2539329        1    prior             1          2                  8
# 2   2539329        1    prior             1          2                  8
# 3   2539329        1    prior             1          2                  8
# 4   2539329        1    prior             1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     0.0         196                  1          0
# 1                     0.0       14084                  2          0
# 2                     0.0       12427                  3          0
# 3                     0.0       26088                  4          0
# 4                     0.0       26405                  5          0
#
#                               product_name  aisle_id  department_id  \
# 0                                     Soda        77              7
# 1  Organic Unsweetened Vanilla Almond Milk        91             16
# 2                      Original Beef Jerky        23             19
# 3               Aged White Cheddar Popcorn        23             19
# 4         XL Pick-A-Size Paper Towel Rolls        54             17
#
#              aisle  department  total_products_by_user
# 0      soft drinks   beverages                       1
# 1  soy lactosefree  dairy eggs                       1
# 2    popcorn jerky      snacks                       1
# 3    popcorn jerky      snacks                       1
# 4      paper goods   household                       1

# %%
train_order_df.groupby('product_id')['total_products_by_user'].sum()
# Out:
# product_id
# 1        8691
# 2         112
# 3        1964
# 4         779
# 5          39
#          ...
# 49684      10
# 49685      55
# 49686     782
# 49687      22
# 49688     110
# Name: total_products_by_user, Length: 49677, dtype: int64

# %% [markdown]
# Now, further features will be extracted based on products, aisles, and departments:

# %% [markdown]
# # Product level features:

# %%
product_feat_df = train_order_df.groupby(['product_id'], as_index=False).agg({'reordered': ['count','sum','mean'],
                                                            'add_to_cart_order':'mean',
                                                             'user_id':lambda x:x.nunique(),
                                                             
                                                                             }
                                                                            )

product_feat_df.columns=['product_id','total_orders_by_products','total_reorders_by_products','reorder_ratio_by_products','add_to_cart_ratio_by_products','total_unique_customers_by_products']
product_feat_df.head()
# Out:
#    product_id  total_orders_by_products  total_reorders_by_products  \
# 0           1                      1852                        1136
# 1           2                        90                          12
# 2           3                       277                         203
# 3           4                       329                         147
# 4           5                        15                           9
#
#    reorder_ratio_by_products  add_to_cart_ratio_by_products  \
# 0                   0.613391                       5.801836
# 1                   0.133333                       9.888889
# 2                   0.732852                       6.415162
# 3                   0.446809                       9.507599
# 4                   0.600000                       6.466667
#
#    total_unique_customers_by_products
# 0                                 716
# 1                                  78
# 2                                  74
# 3                                 182
# 4                                   6

# %% [markdown]
# # Aisle level features:

# %%
aisle_feat_df = train_order_df.groupby(['aisle_id'], as_index=False).agg({'reordered': ['count','sum','mean'],
                                                            'add_to_cart_order':['mean','std'],
                                                             'user_id':lambda x:x.nunique()}
                                                                            )

aisle_feat_df.columns=['aisle_id','total_orders_by_aisle','total_reorders_by_aisle','reorder_ratio_by_aisle','add_to_cart_ratio_by_aisle','add_to_cart_std_by_aisle','total_unique_customers_by_aisle']
aisle_feat_df.head()
# Out:
#    aisle_id  total_orders_by_aisle  total_reorders_by_aisle  \
# 0         1                  71928                    42912
# 1         2                  82491                    40365
# 2         3                 456386                   272922
# 3         4                 200687                    98243
# 4         5                  62510                    17542
#
#    reorder_ratio_by_aisle  add_to_cart_ratio_by_aisle  \
# 0                0.596597                    8.167640
# 1                0.489326                    9.275497
# 2                0.598007                    9.571935
# 3                0.489533                   10.161450
# 4                0.280627                   10.297600
#
#    add_to_cart_std_by_aisle  total_unique_customers_by_aisle
# 0                  7.104166                            20711
# 1                  7.473802                            31222
# 2                  7.899672                            63592
# 3                  7.745705                            53892
# 4                  8.187047                            32312

# %% [markdown]
# # Department Level Features

# %%
department_feat_df = train_order_df.groupby(['department_id'], as_index=False).agg({'reordered': ['count','sum','mean'],
                                                            'add_to_cart_order':['mean','std'],
                                                             'user_id':lambda x:x.nunique() })

department_feat_df.columns=['department_id','total_orders_by_department','total_reorders_by_department','reorder_ratio_by_department','add_to_cart_ratio_by_department','add_to_cart_std_by_department','total_unique_customers_by_department']
department_feat_df.head()
# Out:
#    department_id  total_orders_by_department  total_reorders_by_department  \
# 0              1                     2236432                       1211890
# 1              2                       36291                         14806
# 2              3                     1176787                        739188
# 3              4                     9479291                       6160710
# 4              5                      153696                         87595
#
#    reorder_ratio_by_department  add_to_cart_ratio_by_department  \
# 0                     0.541885                         8.996414
# 1                     0.407980                         8.277645
# 2                     0.628141                         8.084397
# 3                     0.649913                         8.022875
# 4                     0.569924                         5.428346
#
#    add_to_cart_std_by_department  total_unique_customers_by_department
# 0                       7.393502                                163233
# 1                       7.526272                                 17875
# 2                       6.904849                                140612
# 3                       6.658899                                193237
# 4                       5.778253                                 15798

# %%
product_feat_df=product_feat_df.merge(products, on='product_id',how='left')
product_feat_df=product_feat_df.merge(aisles, on='aisle_id', how='left')
product_feat_df=product_feat_df.merge(aisle_feat_df, on='aisle_id', how='left')
product_feat_df=product_feat_df.merge(departments, on='department_id', how='left')
product_feat_df=product_feat_df.merge(department_feat_df, on='department_id', how='left')
product_feat_df.head()
# Out:
#    product_id  total_orders_by_products  total_reorders_by_products  \
# 0           1                      1852                        1136
# 1           2                        90                          12
# 2           3                       277                         203
# 3           4                       329                         147
# 4           5                        15                           9
#
#    reorder_ratio_by_products  add_to_cart_ratio_by_products  \
# 0                   0.613391                       5.801836
# 1                   0.133333                       9.888889
# 2                   0.732852                       6.415162
# 3                   0.446809                       9.507599
# 4                   0.600000                       6.466667
#
#    total_unique_customers_by_products  \
# 0                                 716
# 1                                  78
# 2                                  74
# 3                                 182
# 4                                   6
#
#                                         product_name  aisle_id  department_id  \
# 0                         Chocolate Sandwich Cookies        61             19
# 1                                   All-Seasons Salt       104             13
# 2               Robust Golden Unsweetened Oolong Tea        94              7
# 3  Smart Ones Classic Favorites Mini Rigatoni Wit...        38              1
# 4                          Green Chile Anytime Sauce         5             13
#
#                         aisle  ...  add_to_cart_ratio_by_aisle  \
# 0               cookies cakes  ...                    9.253092
# 1           spices seasonings  ...                    9.996181
# 2                         tea  ...                    8.519846
# 3                frozen meals  ...                    9.207741
# 4  marinades meat preparation  ...                   10.297600
#
#    add_to_cart_std_by_aisle  total_unique_customers_by_aisle  department  \
# 0                  7.845107                            54202      snacks
# 1                  7.994790                            76402      pantry
# 2                  7.818249                            53197   beverages
# 3                  7.435740                            58749      frozen
# 4                  8.187047                            32312      pantry
#
#    total_orders_by_department  total_reorders_by_department  \
# 0                     2887550                       1657973
# 1                     1875577                        650301
# 2                     2690129                       1757892
# 3                     2236432                       1211890
# 4                     1875577                        650301
#
#   reorder_ratio_by_department  add_to_cart_ratio_by_department  \
# 0                    0.574180                         9.187743
# 1                    0.346721                         9.593425
# 2                    0.653460                         6.976699
# 3                    0.541885                         8.996414
# 4                    0.346721                         9.593425
#
#    add_to_cart_std_by_department  total_unique_customers_by_department
# 0                       7.692492                                174219
# 1                       7.875241                                172755
# 2                       6.711172                                172795
# 3                       7.393502                                163233
# 4                       7.875241                                172755
#
# [5 rows x 23 columns]

# %%
product_feat_df.drop(['product_name', 'aisle_id','department_id'], inplace=True, axis=1)

# %%
encoders=BinaryEncoder(cols=['aisle','department'], return_df=True)

# %%
product_feat_df=encoders.fit_transform(product_feat_df)
product_feat_df.head()
# Out:
#    product_id  total_orders_by_products  total_reorders_by_products  \
# 0           1                      1852                        1136
# 1           2                        90                          12
# 2           3                       277                         203
# 3           4                       329                         147
# 4           5                        15                           9
#
#    reorder_ratio_by_products  add_to_cart_ratio_by_products  \
# 0                   0.613391                       5.801836
# 1                   0.133333                       9.888889
# 2                   0.732852                       6.415162
# 3                   0.446809                       9.507599
# 4                   0.600000                       6.466667
#
#    total_unique_customers_by_products  aisle_0  aisle_1  aisle_2  aisle_3  \
# 0                                 716        0        0        0        0
# 1                                  78        0        0        0        0
# 2                                  74        0        0        0        0
# 3                                 182        0        0        0        0
# 4                                   6        0        0        0        0
#
#    ...  department_1  department_2  department_3  department_4  \
# 0  ...             0             0             0             1
# 1  ...             0             0             1             0
# 2  ...             0             0             1             1
# 3  ...             0             1             0             0
# 4  ...             0             0             1             0
#
#    total_orders_by_department  total_reorders_by_department  \
# 0                     2887550                       1657973
# 1                     1875577                        650301
# 2                     2690129                       1757892
# 3                     2236432                       1211890
# 4                     1875577                        650301
#
#    reorder_ratio_by_department  add_to_cart_ratio_by_department  \
# 0                     0.574180                         9.187743
# 1                     0.346721                         9.593425
# 2                     0.653460                         6.976699
# 3                     0.541885                         8.996414
# 4                     0.346721                         9.593425
#
#    add_to_cart_std_by_department  total_unique_customers_by_department
# 0                       7.692492                                174219
# 1                       7.875241                                172755
# 2                       6.711172                                172795
# 3                       7.393502                                163233
# 4                       7.875241                                172755
#
# [5 rows x 31 columns]

# %%
# free some memory
del aisle_feat_df, department_feat_df, aisles, departments
gc.collect()
# Out:
# 0

# %% [markdown]
# # User Based Features:

# %%
user_feat_df=train_order_df.groupby(['user_id'], as_index=False).agg({'order_dow':['mean','std'],
                                                                      'order_hour_of_day':['mean','std'],
                                                                      'days_since_prior_order':['mean', 'std'],
                                                                      'reordered':['count','sum','mean'],
                                                                      'product_id': [lambda x:x.nunique(), 'mean'],
                                                                      'order_number':lambda x:x.nunique(),
                                                                      
                                
                                                                                   })
user_feat_df.columns=['user_id','order_dow_ratio','order_dow_std','order_hour_of_day_ratio','order_hour_of_day_std','days_since_prior_order_ratio','days_since_prior_std','total_ordered_items_by_user','total_reordered_items_by_user','reorder_item_percentage_by_user','total_unique_products_by_users','user_each_product_buying_ratio','total_orders_by_user']
user_feat_df.tail()
# Out:
#         user_id  order_dow_ratio  order_dow_std  order_hour_of_day_ratio  \
# 206204   206205         3.718750       1.084625                13.625000
# 206205   206206         2.312281       1.929394                16.796491
# 206206   206207         2.896861       2.051837                13.130045
# 206207   206208         2.760709       1.734285                13.968981
# 206208   206209         2.658915       1.538547                12.922481
#
#         order_hour_of_day_std  days_since_prior_order_ratio  \
# 206204               1.791557                      9.687500
# 206205               2.282972                      3.985965
# 206206               4.499864                     13.278027
# 206207               3.802901                      7.310192
# 206208               2.737507                     18.232558
#
#         days_since_prior_std  total_ordered_items_by_user  \
# 206204             12.568361                           32
# 206205              3.462040                          285
# 206206             11.624137                          223
# 206207              4.106003                          677
# 206208             10.919815                          129
#
#         total_reordered_items_by_user  reorder_item_percentage_by_user  \
# 206204                              8                         0.250000
# 206205                            135                         0.473684
# 206206                            131                         0.587444
# 206207                            479                         0.707533
# 206208                             61                         0.472868
#
#         total_unique_products_by_users  user_each_product_buying_ratio  \
# 206204                              24                    28724.968750
# 206205                             150                    27728.403509
# 206206                              92                    27029.632287
# 206207                             198                    25954.423929
# 206208                              68                    22312.124031
#
#         total_orders_by_user
# 206204                     3
# 206205                    67
# 206206                    16
# 206207                    49
# 206208                    13

# %%
user_order_feat = train_order_df.groupby(['user_id','order_number']).agg({'reordered':['count','mean']}).reset_index()
user_order_feat.columns=['user_id','order_number','order_size','reorder_ratio_by_order_number']
user_order_feat.head()
# Out:
#    user_id  order_number  order_size  reorder_ratio_by_order_number
# 0        1             1           5                          0.000
# 1        1             2           6                          0.500
# 2        1             3           5                          0.600
# 3        1             4           5                          1.000
# 4        1             5           8                          0.625

# %%
user_feat_2= user_order_feat.groupby('user_id').agg({'order_size':'mean','reorder_ratio_by_order_number':'mean'}).reset_index()
user_feat_2.columns=['user_id','avg_order_size','avg_reorders_in_order_size']
user_feat_2.head()
# Out:
#    user_id  avg_order_size  avg_reorders_in_order_size
# 0        1        5.900000                    0.705833
# 1        2       13.928571                    0.447961
# 2        3        7.333333                    0.658817
# 3        4        3.600000                    0.028571
# 4        5        9.250000                    0.377778

# %%
user_feat_df= user_feat_df.merge(user_feat_2,on='user_id', how='left')
user_feat_df.head()
# Out:
#    user_id  order_dow_ratio  order_dow_std  order_hour_of_day_ratio  \
# 0        1         2.644068       1.256194                10.542373
# 1        2         2.005128       0.971222                10.441026
# 2        3         1.011364       1.245630                16.352273
# 3        4         4.722222       0.826442                13.111111
# 4        5         1.621622       1.276961                15.729730
#
#    order_hour_of_day_std  days_since_prior_order_ratio  days_since_prior_std  \
# 0               3.500355                     18.542373             10.559065
# 1               1.649854                     14.902564              9.671712
# 2               1.454599                     10.181818              5.867396
# 3               1.745208                     11.944444              9.973330
# 4               2.588958                     10.189189              7.600577
#
#    total_ordered_items_by_user  total_reordered_items_by_user  \
# 0                           59                             41
# 1                          195                             93
# 2                           88                             55
# 3                           18                              1
# 4                           37                             14
#
#    reorder_item_percentage_by_user  total_unique_products_by_users  \
# 0                         0.694915                              18
# 1                         0.476923                             102
# 2                         0.625000                              33
# 3                         0.055556                              17
# 4                         0.378378                              23
#
#    user_each_product_buying_ratio  total_orders_by_user  avg_order_size  \
# 0                    17885.966102                    10        5.900000
# 1                    25398.015385                    14       13.928571
# 2                    27459.238636                    12        7.333333
# 3                    23302.666667                     5        3.600000
# 4                    22513.243243                     4        9.250000
#
#    avg_reorders_in_order_size
# 0                    0.705833
# 1                    0.447961
# 2                    0.658817
# 3                    0.028571
# 4                    0.377778

# %% [markdown]
# Reorders in last 3 orders:

# %%
last_three_orders = user_order_feat.groupby('user_id')['order_number'].nlargest(3).reset_index()

# %%
last_three_orders=user_order_feat.merge(last_three_orders, on=['user_id','order_number'], how='inner')
last_three_orders.head()
# Out:
#    user_id  order_number  order_size  reorder_ratio_by_order_number  level_1
# 0        1             8           6                       0.666667        7
# 1        1             9           6                       1.000000        8
# 2        1            10           9                       0.666667        9
# 3        2            12          19                       0.578947       21
# 4        2            13           9                       0.000000       22

# %%
last_three_orders['rank'] = last_three_orders.groupby('user_id')['order_number'].rank(method='dense', ascending=True)
last_three_orders.head()
# Out:
#    user_id  order_number  order_size  reorder_ratio_by_order_number  level_1  \
# 0        1             8           6                       0.666667        7
# 1        1             9           6                       1.000000        8
# 2        1            10           9                       0.666667        9
# 3        2            12          19                       0.578947       21
# 4        2            13           9                       0.000000       22
#
#    rank
# 0   1.0
# 1   2.0
# 2   3.0
# 3   1.0
# 4   2.0

# %%
last_orders_items = last_three_orders.pivot(index='user_id',columns='rank',values=['order_size','reorder_ratio_by_order_number']).reset_index(drop=False)
last_orders_items.columns = ['user_id', 'third_last_order_size','second_last_order_size','last_order_size','reorder_in_third_last','reorder_in_second_last','reorder_in_last']
last_orders_items.head()
# Out:
#    user_id  third_last_order_size  second_last_order_size  last_order_size  \
# 0        1                    6.0                     6.0              9.0
# 1        2                   19.0                     9.0             16.0
# 2        3                    6.0                     5.0              6.0
# 3        4                    7.0                     2.0              3.0
# 4        5                    9.0                     5.0             12.0
#
#    reorder_in_third_last  reorder_in_second_last  reorder_in_last
# 0               0.666667                     1.0         0.666667
# 1               0.578947                     0.0         0.625000
# 2               0.833333                     1.0         1.000000
# 3               0.142857                     0.0         0.000000
# 4               0.444444                     0.4         0.666667

# %%
user_feat_df = user_feat_df.merge(last_orders_items, how='left', on='user_id')
user_feat_df.head()
# Out:
#    user_id  order_dow_ratio  order_dow_std  order_hour_of_day_ratio  \
# 0        1         2.644068       1.256194                10.542373
# 1        2         2.005128       0.971222                10.441026
# 2        3         1.011364       1.245630                16.352273
# 3        4         4.722222       0.826442                13.111111
# 4        5         1.621622       1.276961                15.729730
#
#    order_hour_of_day_std  days_since_prior_order_ratio  days_since_prior_std  \
# 0               3.500355                     18.542373             10.559065
# 1               1.649854                     14.902564              9.671712
# 2               1.454599                     10.181818              5.867396
# 3               1.745208                     11.944444              9.973330
# 4               2.588958                     10.189189              7.600577
#
#    total_ordered_items_by_user  total_reordered_items_by_user  \
# 0                           59                             41
# 1                          195                             93
# 2                           88                             55
# 3                           18                              1
# 4                           37                             14
#
#    reorder_item_percentage_by_user  ...  user_each_product_buying_ratio  \
# 0                         0.694915  ...                    17885.966102
# 1                         0.476923  ...                    25398.015385
# 2                         0.625000  ...                    27459.238636
# 3                         0.055556  ...                    23302.666667
# 4                         0.378378  ...                    22513.243243
#
#    total_orders_by_user  avg_order_size  avg_reorders_in_order_size  \
# 0                    10        5.900000                    0.705833
# 1                    14       13.928571                    0.447961
# 2                    12        7.333333                    0.658817
# 3                     5        3.600000                    0.028571
# 4                     4        9.250000                    0.377778
#
#    third_last_order_size  second_last_order_size  last_order_size  \
# 0                    6.0                     6.0              9.0
# 1                   19.0                     9.0             16.0
# 2                    6.0                     5.0              6.0
# 3                    7.0                     2.0              3.0
# 4                    9.0                     5.0             12.0
#
#    reorder_in_third_last  reorder_in_second_last  reorder_in_last
# 0               0.666667                     1.0         0.666667
# 1               0.578947                     0.0         0.625000
# 2               0.833333                     1.0         1.000000
# 3               0.142857                     0.0         0.000000
# 4               0.444444                     0.4         0.666667
#
# [5 rows x 21 columns]

# %%
product_feat_df.shape
# Out:
# (49677, 31)

# %% [markdown]
# # User's Product based features

# %%
user_product_features = train_order_df.groupby(['user_id','product_id']).agg({'reordered':['count','sum','mean'],
                                                                              'add_to_cart_order':'mean',
                                                                             'order_dow':'mean',
                                                                             'order_hour_of_day':'mean',
                                                                             'days_since_prior_order':'mean'}).reset_index()
user_product_features.columns=['user_id','product_id','user_product_orders','user_product_reorders','user_product_reorder_ratio','user_product_add_to_cart_ratio','user_product_dow_ratio','user_product_hour_ratio','avg_days_since_last_purchase']
user_product_features.head()
# Out:
#    user_id  product_id  user_product_orders  user_product_reorders  \
# 0        1         196                   10                      9
# 1        1       10258                    9                      8
# 2        1       10326                    1                      0
# 3        1       12427                   10                      9
# 4        1       13032                    3                      2
#
#    user_product_reorder_ratio  user_product_add_to_cart_ratio  \
# 0                    0.900000                        1.400000
# 1                    0.888889                        3.333333
# 2                    0.000000                        5.000000
# 3                    0.900000                        3.300000
# 4                    0.666667                        6.333333
#
#    user_product_dow_ratio  user_product_hour_ratio  \
# 0                2.500000                10.300000
# 1                2.555556                10.555556
# 2                4.000000                15.000000
# 3                2.500000                10.300000
# 4                2.666667                 8.000000
#
#    avg_days_since_last_purchase
# 0                     17.600000
# 1                     19.555556
# 2                     28.000000
# 3                     17.600000
# 4                     21.666667

# %%
user_last_orders_by_products_df = train_order_df.merge(last_three_orders, how='inner', on=['user_id','order_number'])
user_last_orders_by_products_df.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   3108588        1    prior             8          1                 14
# 1   3108588        1    prior             8          1                 14
# 2   3108588        1    prior             8          1                 14
# 3   3108588        1    prior             8          1                 14
# 4   3108588        1    prior             8          1                 14
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                    14.0       12427                  1          1
# 1                    14.0         196                  2          1
# 2                    14.0       10258                  3          1
# 3                    14.0       25133                  4          1
# 4                    14.0       46149                  5          0
#
#             product_name  aisle_id  department_id                   aisle  \
# 0    Original Beef Jerky        23             19           popcorn jerky
# 1                   Soda        77              7             soft drinks
# 2             Pistachios       117             19  nuts seeds dried fruit
# 3  Organic String Cheese        21             16         packaged cheese
# 4      Zero Calorie Cola        77              7             soft drinks
#
#    department  total_products_by_user  order_size  \
# 0      snacks                       8           6
# 1   beverages                       8           6
# 2      snacks                       7           6
# 3  dairy eggs                       6           6
# 4   beverages                       1           6
#
#    reorder_ratio_by_order_number  level_1  rank
# 0                       0.666667        7   1.0
# 1                       0.666667        7   1.0
# 2                       0.666667        7   1.0
# 3                       0.666667        7   1.0
# 4                       0.666667        7   1.0

# %%
user_last_orders_by_products_df['rank']=user_last_orders_by_products_df.groupby(['user_id','product_id'])['order_number'].rank(method='dense', ascending=True)
user_last_orders_by_products_df.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   3108588        1    prior             8          1                 14
# 1   3108588        1    prior             8          1                 14
# 2   3108588        1    prior             8          1                 14
# 3   3108588        1    prior             8          1                 14
# 4   3108588        1    prior             8          1                 14
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                    14.0       12427                  1          1
# 1                    14.0         196                  2          1
# 2                    14.0       10258                  3          1
# 3                    14.0       25133                  4          1
# 4                    14.0       46149                  5          0
#
#             product_name  aisle_id  department_id                   aisle  \
# 0    Original Beef Jerky        23             19           popcorn jerky
# 1                   Soda        77              7             soft drinks
# 2             Pistachios       117             19  nuts seeds dried fruit
# 3  Organic String Cheese        21             16         packaged cheese
# 4      Zero Calorie Cola        77              7             soft drinks
#
#    department  total_products_by_user  order_size  \
# 0      snacks                       8           6
# 1   beverages                       8           6
# 2      snacks                       7           6
# 3  dairy eggs                       6           6
# 4   beverages                       1           6
#
#    reorder_ratio_by_order_number  level_1  rank
# 0                       0.666667        7   1.0
# 1                       0.666667        7   1.0
# 2                       0.666667        7   1.0
# 3                       0.666667        7   1.0
# 4                       0.666667        7   1.0

# %%
reorder_products_in_last_orders = user_last_orders_by_products_df.pivot(index=['user_id','product_id'],columns='rank', values='reordered').reset_index(drop=False)
reorder_products_in_last_orders.columns=['user_id','product_id','reorder_in_third_last_order','reorder_in_second_last_order','reorder_in_last_order']
reorder_products_in_last_orders.head()
# Out:
#    user_id  product_id  reorder_in_third_last_order  \
# 0        1         196                          1.0
# 1        1       10258                          1.0
# 2        1       12427                          1.0
# 3        1       13032                          1.0
# 4        1       25133                          1.0
#
#    reorder_in_second_last_order  reorder_in_last_order
# 0                           1.0                    1.0
# 1                           1.0                    1.0
# 2                           1.0                    1.0
# 3                           NaN                    NaN
# 4                           1.0                    1.0

# %%
#fill nan values as 0, which represents the products not reordered
reorder_products_in_last_orders.fillna(0, inplace=True)
reorder_products_in_last_orders.head()
# Out:
#    user_id  product_id  reorder_in_third_last_order  \
# 0        1         196                          1.0
# 1        1       10258                          1.0
# 2        1       12427                          1.0
# 3        1       13032                          1.0
# 4        1       25133                          1.0
#
#    reorder_in_second_last_order  reorder_in_last_order
# 0                           1.0                    1.0
# 1                           1.0                    1.0
# 2                           1.0                    1.0
# 3                           0.0                    0.0
# 4                           1.0                    1.0

# %%
user_product_features=user_product_features.merge(reorder_products_in_last_orders, on=['user_id','product_id'], how='left')
user_product_features.head()
# Out:
#    user_id  product_id  user_product_orders  user_product_reorders  \
# 0        1         196                   10                      9
# 1        1       10258                    9                      8
# 2        1       10326                    1                      0
# 3        1       12427                   10                      9
# 4        1       13032                    3                      2
#
#    user_product_reorder_ratio  user_product_add_to_cart_ratio  \
# 0                    0.900000                        1.400000
# 1                    0.888889                        3.333333
# 2                    0.000000                        5.000000
# 3                    0.900000                        3.300000
# 4                    0.666667                        6.333333
#
#    user_product_dow_ratio  user_product_hour_ratio  \
# 0                2.500000                10.300000
# 1                2.555556                10.555556
# 2                4.000000                15.000000
# 3                2.500000                10.300000
# 4                2.666667                 8.000000
#
#    avg_days_since_last_purchase  reorder_in_third_last_order  \
# 0                     17.600000                          1.0
# 1                     19.555556                          1.0
# 2                     28.000000                          NaN
# 3                     17.600000                          1.0
# 4                     21.666667                          1.0
#
#    reorder_in_second_last_order  reorder_in_last_order
# 0                           1.0                    1.0
# 1                           1.0                    1.0
# 2                           NaN                    NaN
# 3                           1.0                    1.0
# 4                           0.0                    0.0

# %%
user_product_features.isnull().any()
# Out:
# user_id                           False
# product_id                        False
# user_product_orders               False
# user_product_reorders             False
# user_product_reorder_ratio        False
# user_product_add_to_cart_ratio    False
# user_product_dow_ratio            False
# user_product_hour_ratio           False
# avg_days_since_last_purchase      False
# reorder_in_third_last_order        True
# reorder_in_second_last_order       True
# reorder_in_last_order              True
# dtype: bool

# %%
user_product_features.fillna(0,inplace=True)

# %% [markdown]
# # Saving the extracted features

# %%
product_feat_df.to_pickle('product_feat_df.pkl')
user_feat_df.to_pickle('user_feat_df.pkl')
user_product_features.to_pickle('user_product_feat.pkl')
train_order_df.to_pickle('train_order_df')
